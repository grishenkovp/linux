# %% [markdown]
# # Команды Linux на платформе Google Colaboratory

# %% [markdown]
# ### Операции с файлами и каталогами

# %%
# список всех файлов в каталоге
# !ls sample_data
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
# содержимое корневого каталога
# !ls /
# Out:
# bin	 datalab  home	 lib64	opt   run   swift	       tmp    var
# boot	 dev	  lib	 media	proc  sbin  sys		       tools
# content  etc	  lib32  mnt	root  srv   tensorflow-1.15.2  usr

# %%
# показать первые пять строчек файла
# !head -n 5 sample_data/california_housing_train.csv
# Out:
# "longitude","latitude","housing_median_age","total_rooms","total_bedrooms","population","households","median_income","median_house_value"
# -114.310000,34.190000,15.000000,5612.000000,1283.000000,1015.000000,472.000000,1.493600,66900.000000
# -114.470000,34.400000,19.000000,7650.000000,1901.000000,1129.000000,463.000000,1.820000,80100.000000
# -114.560000,33.690000,17.000000,720.000000,174.000000,333.000000,117.000000,1.650900,85700.000000
# -114.570000,33.640000,14.000000,1501.000000,337.000000,515.000000,226.000000,3.191700,73400.000000

# %%
# вывести последние 5 строчек файла
# !tail -n 5 sample_data/california_housing_test.csv
# Out:
# -119.860000,34.420000,23.000000,1450.000000,642.000000,1258.000000,607.000000,1.179000,225000.000000
# -118.140000,34.060000,27.000000,5257.000000,1082.000000,3496.000000,1036.000000,3.390600,237200.000000
# -119.700000,36.300000,10.000000,956.000000,201.000000,693.000000,220.000000,2.289500,62000.000000
# -117.120000,34.100000,40.000000,96.000000,14.000000,46.000000,14.000000,3.270800,162500.000000
# -119.630000,34.420000,42.000000,1765.000000,263.000000,753.000000,260.000000,8.560800,500001.000000

# %%
# посмотреть весь файл 
# !cat sample_data/README.md
# Out:
# This directory includes a few sample datasets to get you started.
#
# *   `california_housing_data*.csv` is California housing data from the 1990 US
#     Census; more information is available at:
#     https://developers.google.com/machine-learning/crash-course/california-housing-data-description
#
# *   `mnist_*.csv` is a small sample of the
#     [MNIST database](https://en.wikipedia.org/wiki/MNIST_database), which is
#     described at: http://yann.lecun.com/exdb/mnist/
#
# *   `anscombe.json` contains a copy of
#     [Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet); it
#     was originally described in
#
#     Anscombe, F. J. (1973). 'Graphs in Statistical Analysis'. American
#     Statistician. 27 (1): 17-21. JSTOR 2682899.
#
#     and our copy was prepared by the
#     [vega_datasets library](https://github.com/altair-viz/vega_datasets/blob/4f67bdaad10f45e3549984e17e1b3088c731503d/vega_datasets/_data/anscombe.json).

# %%
# подсчет количества строк в файле 
# !wc -l sample_data/README.md
# Out:
# 19 sample_data/README.md

# %%
# посмотреть текущий каталог
# !pwd
# Out:
# /content

# %%
# создать новый каталог
# !mkdir test_commands1 test_commands2 test_commands3
# Out:
# mkdir: cannot create directory ‘test_commands1’: File exists

# %%
# сменить директорию на ...
#!cd test_commands1

# %%
# удалить каталог
# !rm -r test_commands3

# %%
# создать файл
# !touch test_commands1/file1.txt
# !touch test_commands2/file2.txt

# %%
# скопировать файл
# !cp test_commands1/file1.txt test_commands2/

# %%
# удалить каталог и переименовать оставщийся
# !rm -r test_commands1
# !mv test_commands2 test_commands1

# %%
# установка редактора nano
# !apt-get install nano

# %%
# проверка версии установленной программы
# !nano --version

# %%
# !nano test_commands1/file1.txt

# %% [markdown]
# ### Загрузка данных из Интернета

# %%
# !wget https://github.com/GrishenkovP/python/blob/master/machine_learning/scikit-learn/all_algorithms/Sales.csv
# Out:
# --2021-01-01 13:36:53--  https://github.com/GrishenkovP/python/blob/master/machine_learning/scikit-learn/all_algorithms/Sales.csv
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘Sales.csv’
#
# Sales.csv               [ <=>                ] 344.89K  --.-KB/s    in 0.1s
#
# 2021-01-01 13:36:54 (3.22 MB/s) - ‘Sales.csv’ saved [353163]

# %% [markdown]
# ### Архивация данных

# %%
# создать архив tar с сжатием gzip
# !tar czf sale.tar.gz Sales.csv

# %%
rm Sales.csv

# %%
# распаковать архив
# !tar xvfz sale.tar.gz
# Out:
# Sales.csv

# %%
rm sale.tar.gz
